# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv("dataset/sales.csv", sep = ";")
# Out:
# /var/folders/jv/cksm9nnd2wzfc5zr9fvpzs700000gn/T/ipykernel_79185/1380394964.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset/sales.csv", sep = ";")

# %%
df.head(5)
# Out:
#      product_id   local        date  planned_quantity  actual_quantity  \
# 0  Product_0001  Whse_A  03/01/2012               200              200
# 1  Product_0001  Whse_A  03/01/2012               800              200
# 2  Product_0001  Whse_A  04/01/2012               200              500
# 3  Product_0001  Whse_A  09/01/2012              2000              350
# 4  Product_0001  Whse_A  10/01/2012              2000             1175
#
#    planned_price promotion_type  actual_price  service_level
# 0            136            NaN         136.0           0.98
# 1            136            NaN         136.0           0.98
# 2            136            NaN         136.0           0.98
# 3            136            NaN         136.0           0.98
# 4            136            NaN         136.0           0.98

# %%
set(list(df['date']))
# Out:
# {'01/01/2012',
#  '01/02/2012',
#  '01/03/2012',
#  '01/04/2012',
#  '01/05/2012',
#  '01/06/2012',
#  '01/07/2012',
#  '01/08/2012',
#  '01/10/2012',
#  '01/11/2012',
#  '02/01/2012',
#  '02/02/2012',
#  '02/03/2012',
#  '02/04/2012',
#  '02/05/2012',
#  '02/07/2012',
#  '02/08/2012',
#  '02/09/2012',
#  '02/10/2012',
#  '02/11/2012',
#  '02/12/2012',
#  '03/01/2012',
#  '03/02/2012',
#  '03/04/2012',
#  '03/05/2012',
#  '03/06/2012',
#  '03/07/2012',
#  '03/08/2012',
#  '03/09/2012',
#  '03/10/2012',
#  '03/11/2012',
#  '03/12/2012',
#  '04/01/2012',
#  '04/03/2012',
#  '04/04/2012',
#  '04/05/2012',
#  '04/06/2012',
#  '04/07/2012',
#  '04/08/2012',
#  '04/09/2012',
#  '04/10/2012',
#  '04/11/2012',
#  '04/12/2012',
#  '05/01/2012',
#  '05/02/2012',
#  '05/03/2012',
#  '05/04/2012',
#  '05/05/2012',
#  '05/06/2012',
#  '05/07/2012',
#  '05/08/2012',
#  '05/09/2012',
#  '05/10/2012',
#  '05/11/2012',
#  '05/12/2012',
#  '06/01/2012',
#  '06/02/2012',
#  '06/03/2012',
# ...

# %%
Counter(df['product_id'])
# Out:
# Counter({'Product_1359': 3728,
#          'Product_1295': 2233,
#          'Product_1286': 2001,
#          'Product_1378': 1963,
#          'Product_0620': 1900,
#          'Product_1294': 1888,
#          'Product_1382': 1741,
#          'Product_1453': 1726,
#          'Product_1287': 1695,
#          'Product_1377': 1690,
#          'Product_1016': 1680,
#          'Product_1274': 1453,
#          'Product_1248': 1382,
#          'Product_1241': 1204,
#          'Product_0613': 1125,
#          'Product_1456': 1105,
#          'Product_0408': 1051,
#          'Product_1360': 1046,
#          'Product_1451': 1044,
#          'Product_0031': 1036,
#          'Product_1381': 1032,
#          'Product_0407': 1015,
#          'Product_1023': 998,
#          'Product_1452': 990,
#          'Product_1886': 978,
#          'Product_0409': 921,
#          'Product_0033': 920,
#          'Product_1264': 919,
#          'Product_0608': 917,
#          'Product_1262': 899,
# ...

# %%
pd.DataFrame(df.groupby('product_id')['actual_quantity'].sum())
# Out:
#               actual_quantity
# product_id
# Product_0001           111583
# Product_0002          1256435
# Product_0003            13527
# Product_0004             5154
# Product_0005              907
# ...                       ...
# Product_2168            10487
# Product_2169             6095
# Product_2170              381
# Product_2171              416
# Product_2172             1025
#
# [1966 rows x 1 columns]

# %%
df_most_sold.columns
# Out:
# Index(['actual_quantity'], dtype='object')
